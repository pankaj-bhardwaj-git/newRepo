# %%
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import cv2

# %%
# import cv2
# from ultralytics import YOLO
# from deep_sort import DeepSort

# Initialize YOLO model
yolo_model = YOLO('yolov8s.pt')

# Get the list of class names from the model
class_names = yolo_model.names

# Initialize DeepSORT tracker
tracker = DeepSort(max_age=30, nn_budget=100)

# Constants for distance calculation
dist_class_width = {"bottle":8,"person":39,"laptop":35}
W = 8  # Actual width of the object in the real world (e.g., width of a laptop in cm)
F = 1071.4285714285713  # Focal length (derived from camera calibration)

# Path to your video file
video_path = 'http://192.168.142.63:8080/video'  # Ensure the correct extension
cap = cv2.VideoCapture(video_path)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Perform object detection
    results = yolo_model(frame)

    # Store detections for DeepSORT (only for laptops)
    detections = []
    widths = []
    for r in results:
        boxes = r.boxes  # Detected bounding boxes
        for box in boxes:
            # Get the object class index and map it to the class name
            class_idx = int(box.cls[0])  # Get the class index (as integer)
            class_name = class_names[class_idx]  # Map index to class name

            # Get bounding box coordinates
            xyxy = box.xyxy[0].tolist()
            x1, y1, x2, y2 = xyxy[:4]
            width = x2 - x1  # Width of the bounding box
            height = y2 - y1  # Height of the bounding box
            conf = box.conf.item()  # Confidence score

            # Filter for laptop objects only
            if class_name == 'bottle':
                detections.append([[x1, y1, width, height], conf])
                widths.append(width)  # Append the width for distance calculation

    # Update DeepSORT tracker with filtered detections
    tracks = tracker.update_tracks(detections, frame=frame)

    # Draw tracking results and calculate distance on the frame
    for i, track in enumerate(tracks):
        if not track.is_confirmed():
            continue
        track_id = track.track_id
        bbox = track.to_tlbr()  # Get the bounding box in (x1, y1, x2, y2) format

        # Draw bounding box and track ID
        cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)
        cv2.putText(frame, f'ID: {track_id}', (int(bbox[0]), int(bbox[1] - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

        # Calculate the distance using the width of the object (P = width of the bounding box)
        if i < len(widths):  # Ensure there is a width for this track
            P = widths[i]
            D_dash = (W * F) / P 
            print(D_dash)
            cv2.putText(frame, f'Dist: {D_dash:.2f} cm', (int(bbox[0]), int(bbox[1] - 30)), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

    # Display the frame with tracking information
    cv2.imshow('Object Tracking and Distance Estimation', frame)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# MULTIPLE OBJECTS DICTIONARY

# %%
import cv2
from ultralytics import YOLO
# from deep_sort import DeepSort

# Initialize YOLO model
yolo_model = YOLO('yolov8s.pt')

# Get the list of class names from the model
class_names = yolo_model.names

# Initialize DeepSORT tracker
tracker = DeepSort(max_age=30, nn_budget=100)

# Constants for distance calculation
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
dist_class_width = {"bottle": 8, "person": 39, "laptop": 35}  # Actual widths in cm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
F = 1071.4285714285713  # Focal length (derived from camera calibration)

# Path to your video file
video_path = 'http://192.168.220.3:8080/video'  # Ensure the correct extension
cap = cv2.VideoCapture(video_path)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Perform object detection
    results = yolo_model(frame)

    # Store detections for DeepSORT (for laptops, persons, and bottles)
    detections = []
    widths = []
    for r in results:
        boxes = r.boxes  # Detected bounding boxes
        for box in boxes:
            # Get the object class index and map it to the class name
            class_idx = int(box.cls[0])  # Get the class index (as integer)
            class_name = class_names[class_idx]  # Map index to class name

            # Get bounding box coordinates
            xyxy = box.xyxy[0].tolist()
            x1, y1, x2, y2 = xyxy[:4]
            width_pixels = x2 - x1  # Width of the bounding box in pixels
            height_pixels = y2 - y1  # Height of the bounding box in pixels
            conf = box.conf.item()  # Confidence score

            # Filter for specific objects and use their widths for distance calculation
            if class_name in dist_class_width:
                detections.append([[x1, y1, width_pixels, height_pixels], conf])
                widths.append(dist_class_width[class_name])  # Use width from dictionary

    # Update DeepSORT tracker with filtered detections
    tracks = tracker.update_tracks(detections, frame=frame)

    # Draw tracking results and calculate distance on the frame
    for i, track in enumerate(tracks):
        if not track.is_confirmed():
            continue
        
        track_id = track.track_id
        bbox = track.to_tlbr()  # Get the bounding box in (x1, y1, x2, y2) format

        # Draw bounding box and track ID
        cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)
        cv2.putText(frame, f'ID: {track_id}', (int(bbox[0]), int(bbox[1] - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

        # Calculate distance using width from dictionary and bounding box width in pixels
        if i < len(widths):  # Ensure there is a width for this track
            P_pixels = detections[i][0][2]  # Width of bounding box in pixels
            
            if P_pixels > 0:  # Avoid division by zero
                W_class = widths[i]  # Real-world width from dictionary
                D_dash = (W_class * F) / P_pixels 
                print(f'Distance to {class_names[class_idx]}: {D_dash:.2f} cm')
                cv2.putText(frame, f'Dist: {D_dash:.2f} cm', (int(bbox[0]), int(bbox[1] - 30)), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (255, 255, 255), 2)

    # Display the frame with tracking information
    cv2.imshow('Object Tracking and Distance Estimation', frame)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 laptop, 1 keyboard, 150.0ms
# Speed: 4.0ms preprocess, 150.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 1 keyboard, 131.0ms
# Speed: 3.0ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 127.0ms
# Speed: 2.0ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 112.0ms
# Speed: 3.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 126.0ms
# Speed: 2.0ms preprocess, 126.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to tv: 20.22 cm
#
# 0: 384x640 1 person, 1 tv, 1 laptop, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 20.36 cm
#
# 0: 384x640 1 tv, 115.0ms
# Speed: 3.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 laptop, 115.0ms
# Speed: 3.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to laptop: 20.69 cm
#
# 0: 384x640 1 laptop, 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance
0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 29.20 cm
# Distance to mouse: 83.22 cm
#
# 0: 384x640 1 laptop, 1 mouse, 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 29.24 cm
#
# 0: 384x640 1 person, 1 laptop, 1 mouse, 122.0ms
# Speed: 2.0ms preprocess, 122.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 29.28 cm
# Distance to person: 82.79 cm
#
# 0: 384x640 1 cat, 1 suitcase, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 115.0ms
# Speed: 3.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cell phone: 29.88 cm
#
# 0: 384x640 1 cat, 1 suitcase, 1 tv, 1 laptop, 1 mouse, 1 cell phone, 123.0ms
# Speed: 2.0ms preprocess, 123.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cell phone: 30.06 cm
#
# 0: 384x640 1 cat, 1 suitcase, 1 tv, 1 laptop, 1 mouse, 118.4ms
# Speed: 2.0ms preprocess, 118.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cat: 29.88 cm
#
# 0: 384x640 1 cat, 1 suitcase, 1 bed, 1 tv, 1 laptop, 1 cell phone, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cell phone: 29.86 cm
#
# 0: 384x640 1 cat, 1 suitcase, 1 tv, 1 laptop, 1 mouse, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cat: 29.79 cm
#
# 0: 384x640 1 suitcase, 1 tv, 1 laptop, 1 mouse, 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 30.05 cm
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 1 mouse, 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 30.00 cm
# Distance to mouse: 172.59 cm
#
# 0: 384x640 1 person, 1 suitcase, 1 tv, 1 laptop, 1 mouse, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 29.84 cm
# Distance to person: 171.34 cm
#
# 0: 384x640 1 person, 1 cat, 1 tv, 1 laptop, 1 vase, 143.2ms
# Speed: 3.2ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to vase: 30.36 cm
# Distance to vase: 109.58 cm
#
# 0: 384x640 1 person, 1 cat, 1 tv, 1 laptop, 1 mouse, 124.1ms
# Speed: 3.0ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 30.42 cm
# Distance to mouse: 108.00 cm
#
# 0: 384x640 1 person, 1 cat, 1 tv, 1 laptop, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 30.35 cm
# Distance to person: 108.64 cm
#
# 0: 384x640 1 tv, 1 laptop, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to tv: 30.40 cm
#
# 0: 384x640 1 suitcase, 1 tv, 1 laptop, 113.5ms
# Speed: 3.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to suitcase: 30.42 cm
#
# 0: 384x640 1 tv, 1 laptop, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to tv: 30.43 cm
#
# 0: 384x640 1 tv, 1 laptop, 1 keyboard, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 30.50 cm
#
# 0: 384x640 1 bed, 1 tv, 1 laptop, 1 keyboard, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 30.56 cm
#
# 0: 384x640 1 tv, 1 laptop, 1 keyboard, 108.0ms
# Speed: 1.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 29.97 cm
#
# 0: 384x640 1 bed, 1 tv, 1 laptop, 1 keyboard, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 30.50 cm
#
# 0: 384x640 1 suitcase, 1 tv, 1 laptop, 1 keyboard, 105.8ms
# Speed: 2.0ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 29.78 cm
#
# 0: 384x640 1 tv, 1 laptop, 1 mouse, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 30.12 cm
#
# 0: 384x640 1 suitcase, 1 tv, 1 laptop, 1 keyboard, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 30.71 cm
#
# 0: 384x640 1 tv, 1 laptop, 1 keyboard, 116.0ms
# Speed: 3.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to keyboard: 30.17 cm
#
# 0: 384x640 1 tv, 1 laptop, 1 mouse, 1 keyboard, 110.1ms
# Speed: 3.0ms preprocess, 110.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Distance to tv: 30.22 cm
#
# 0: 384x640 2 bottles, 1 laptop, 1 cell phone, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bottle: 43.63 cm
# Distance to bottle: 46.06 cm
# Distance to bottle: 36.86 cm
#
# 0: 384x640 2 bottles, 1 laptop, 1 cell phone, 110.1ms
# Speed: 1.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cell phone: 44.05 cm
# Distance to cell phone: 44.39 cm
# Distance to cell phone: 38.24 cm
#
# 0: 384x640 3 bottles, 1 laptop, 1 mouse, 1 cell phone, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bottle: 44.62 cm
# Distance to bottle: 45.36 cm
# Distance to bottle: 37.19 cm
# Distance to bottle: 70.94 cm
#
# 0: 384x640 3 bottles, 1 laptop, 1 mouse, 1 cell phone, 106.0ms
# Speed: 3.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 45.35 cm
# Distance to mouse: 47.85 cm
# Distance to mouse: 70.98 cm
# Distance to mouse: 38.92 cm
#
# 0: 384x640 3 bottles, 1 laptop, 1 mouse, 1 cell phone, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bottle: 46.01 cm
# Distance to bottle: 48.54 cm
# Distance to bottle: 39.20 cm
# Distance to bottle: 73.37 cm
#
# 0: 384x640 2 bottles, 1 laptop, 1 mouse, 1 cell phone, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bottle: 46.95 cm
# Distance to bottle: 48.68 cm
# Distance to bottle: 74.90 cm
#
# 0: 384x640 3 bottles, 1 laptop, 1 cell phone, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cell phone: 47.72 cm
# Distance to cell phone: 49.29 cm
# Distance to cell phone: 39.12 cm
# Distance to cell phone: 74.67 cm
#
# 0: 384x640 3 bottles, 1 laptop, 1 mouse, 1 cell phone, 113.0ms
# Speed: 2.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to mouse: 48.65 cm
# Distance to mouse: 48.43 cm
# Distance to mouse: 39.94 cm
# Distance to mouse: 74.24 cm
#
# 0: 384x640 (no detections), 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase,
0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 45.18 cm
#
# 0: 384x640 1 person, 106.0ms
# Speed: 3.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.46 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.28 cm
#
# 0: 384x640 1 person, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.49 cm
#
# 0: 384x640 1 person, 102.6ms
# Speed: 2.0ms preprocess, 102.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.59 cm
#
# 0: 384x640 1 person, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.93 cm
#
# 0: 384x640 2 persons, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.53 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.84 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.15 cm
#
# 0: 384x640 2 persons, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.53 cm
#
# 0: 384x640 2 persons, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.25 cm
#
# 0: 384x640 1 person, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.00 cm
#
# 0: 384x640 2 persons, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.25 cm
#
# 0: 384x640 1 person, 1 tie, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to tie: 68.27 cm
#
# 0: 384x640 1 person, 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.36 cm
#
# 0: 384x640 1 person, 105.0ms
# Speed: 3.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.16 cm
#
# 0: 384x640 2 persons, 1 tie, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.63 cm
#
# 0: 384x640 2 persons, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.90 cm
#
# 0: 384x640 2 persons, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.03 cm
# Distance to person: 402.13 cm
#
# 0: 384x640 2 persons, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.98 cm
# Distance to person: 394.21 cm
#
# 0: 384x640 2 persons, 113.0ms
# Speed: 3.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.94 cm
# Distance to person: 382.22 cm
#
# 0: 384x640 2 persons, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.79 cm
# Distance to person: 378.26 cm
#
# 0: 384x640 2 persons, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.64 cm
# Distance to person: 370.35 cm
#
# 0: 384x640 2 persons, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.59 cm
# Distance to person: 362.02 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.11 cm
#
# 0: 384x640 2 persons, 120.6ms
# Speed: 2.0ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.04 cm
# Distance to person: 254.41 cm
#
# 0: 384x640 2 persons, 109.0ms
# Speed: 3.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.08 cm
# Distance to person: 258.22 cm
#
# 0: 384x640 1 person, 114.5ms
# Speed: 3.0ms preprocess, 114.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.04 cm
#
# 0: 384x640 2 persons, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.03 cm
# Distance to person: 260.17 cm
#
# 0: 384x640 2 persons, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.06 cm
# Distance to person: 255.09 cm
#
# 0: 384x640 2 persons, 103.0ms
# Speed: 1.0ms preprocess, 103.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 65.91 cm
# Distance to person: 257.68 cm
#
# 0: 384x640 1 person, 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 65.80 cm
#
# 0: 384x640 1 person, 103.0ms
# Speed: 1.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.85 cm
#
# 0: 384x640 2 persons, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.56 cm
# Distance to person: 257.48 cm
#
# 0: 384x640 1 person, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.57 cm
#
# 0: 384x640 1 person, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.03 cm
#
# 0: 384x640 1 person, 107.0ms
# Speed: 2.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.38 cm
#
# 0: 384x640 1 person, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.83 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.68 cm
#
# 0: 384x640 2 persons, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 65.41 cm
# Distance to person: 52.59 cm
#
# 0: 384x640 4 persons, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 65.66 cm
# Distance to person: 100.57 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.00 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.14 cm
#
# 0: 384x640 1 person, 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.44 cm
#
# 0: 384x640 1 person, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 66.76 cm
#
# 0: 384x640 1 person, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 67.11 cm
#
# 0: 384x640 1 person, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 81.20 cm
#
# 0: 384x640 1 person, 1 bed, 103.0ms
# Speed: 3.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 82.13 cm
#
# 0: 384x640 1 person, 2 beds, 109.0ms
# Speed: 1.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 81.80 cm
#
# 0: 384x640 1 person, 2 beds, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 81.90 cm
#
# 0: 384x640 1 person, 2 beds, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 83.09 cm
#
# 0: 384x640 1 person, 2 beds, 104.7ms
# Speed: 2.0ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 83.43 cm
#
# 0: 384x640 1 person, 1 bed, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 84.23 cm
#
# 0: 384x640 1 person, 2 beds, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 84.61 cm
#
# 0: 384x640 1 person, 2 beds, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 85.50 cm
#
# 0: 384x640 1 person, 2 beds, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed:
0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.07 cm
#
# 0: 384x640 1 person, 2 beds, 99.0ms
# Speed: 3.0ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 90.80 cm
#
# 0: 384x640 1 person, 2 beds, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.29 cm
#
# 0: 384x640 1 person, 2 beds, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.50 cm
#
# 0: 384x640 1 person, 2 beds, 101.0ms
# Speed: 3.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.24 cm
#
# 0: 384x640 1 person, 2 beds, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.04 cm
#
# 0: 384x640 1 person, 1 bed, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.08 cm
#
# 0: 384x640 1 person, 2 beds, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.33 cm
#
# 0: 384x640 1 person, 2 beds, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.18 cm
#
# 0: 384x640 1 person, 2 beds, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.76 cm
#
# 0: 384x640 1 person, 2 beds, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.62 cm
#
# 0: 384x640 1 person, 2 beds, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 91.98 cm
#
# 0: 384x640 1 person, 1 bed, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.02 cm
#
# 0: 384x640 1 person, 2 beds, 106.0ms
# Speed: 3.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.19 cm
#
# 0: 384x640 1 person, 2 beds, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.27 cm
#
# 0: 384x640 1 person, 2 beds, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.35 cm
#
# 0: 384x640 1 person, 2 beds, 105.0ms
# Speed: 1.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.55 cm
#
# 0: 384x640 1 person, 2 beds, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 92.04 cm
#
# 0: 384x640 1 person, 1 backpack, 1 suitcase, 2 beds, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 89.93 cm
#
# 0: 384x640 1 person, 1 backpack, 1 suitcase, 2 beds, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to backpack: 89.06 cm
#
# 0: 384x640 1 person, 2 beds, 125.6ms
# Speed: 2.0ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 88.54 cm
#
# 0: 384x640 1 person, 1 backpack, 2 beds, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 88.49 cm
#
# 0: 384x640 1 person, 1 backpack, 2 beds, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 88.52 cm
#
# 0: 384x640 1 person, 2 beds, 104.0ms
# Speed: 1.8ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 88.70 cm
#
# 0: 384x640 1 person, 1 bed, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 89.00 cm
#
# 0: 384x640 (no detections), 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 vase, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.9ms
# Speed: 2.0ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.0ms
# Speed: 3.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.8ms
# Speed: 3.0ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to train: 132.15 cm
#
# 0: 384x640 1 person, 1 train, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 267.24 cm
#
# 0: 384x640 1 person, 1 train, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Distance to train: 123.70 cm
#
# 0: 384x640 1 person, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 81.48 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 1.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 82.25 cm
#
# 0: 384x640 1 person, 103.0ms
# Speed: 3.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 81.81 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 82.28 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 82.34 cm
#
# 0: 384x640 1 person, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 73.89 cm
#
# 0: 384x640 1 person, 127.0ms
# Speed: 3.0ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 65.43 cm
#
# 0: 384x640 1 person, 101.0ms
# Speed: 3.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 68.18 cm
#
# 0: 384x640 1 person, 1 bed, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 81.98 cm
#
# 0: 384x640 1 person, 1 giraffe, 1 bed, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to giraffe: 81.45 cm
#
# 0: 384x640 1 person, 1 bed, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 82.20 cm
#
# 0: 384x640 1 person, 1 bed, 103.0ms
# Speed: 3.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 82.10 cm
#
# 0: 384x640 1 person, 1 bed, 104.0ms
# Speed: 3.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 82.47 cm
#
# 0: 384x640 1 person, 1 bed, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 82.72 cm
#
# 0: 384x640 1 person, 1 bed, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 83.07 cm
#
# 0: 384x640 1 person, 1 bed, 104.0ms
# Speed: 3.1ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 83.12 cm
#
# 0: 384x640 1 person, 1 bed, 105.0ms
# Speed: 3.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 80.07 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 80.20 cm
#
# 0: 384x640 1 person, 106.0ms
# Speed: 3.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 81.01 cm
#
# 0: 384x640 1 person, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 80.93 cm
#
# 0: 384x640 1 person, 107.9ms
# Speed: 3.0ms preprocess, 107.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 80.69 cm
#
# 0: 384x640 1 person, 1 bed, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to bed: 81.16 cm
#
# 0: 384x640 1 person, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 84.92 cm
#
# 0: 384x640 1 person, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 83.80 cm
#
# 0: 384x640 1 person, 114.0ms
# Speed: 3.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 84.72 cm
#
# 0: 384x640 2 persons, 113.0ms
# Speed: 3.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 83.84 cm
#
# 0: 384x640 1 person, 115.0ms
# Speed: 3.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 84.19 cm
#
# 0: 384x640 1 person, 112.0ms
# Speed: 3.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 84.16 cm
#
# 0: 384x640 1 person, 1 cell phone, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to cell phone: 78.19 cm
#
# 0: 384x640 1 person, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 76.03 cm
#
# 0: 384x640 1 person, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 75.12 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 74.24 cm
#
# 0: 384x640 1 person, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 74.26 cm
#
# 0: 384x640 1 person, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 74.17 cm
#
# 0: 384x640 1 person, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 74.26 cm
#
# 0: 384x640 1 person, 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 74.43 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 74.39 cm
#
# 0: 384x640 1 person, 104.0ms
# Speed: 2.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 62.91 cm
#
# 0: 384x640 1 person, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 61.03 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 58.75 cm
#
# 0: 384x640 1 person, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 58.16 cm
#
# 0: 384x640 1 person, 103.2ms
# Speed: 3.0ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Distance to person: 57.04 cm

# %% [markdown]
# Depth Map

# %%
import torch
import cv2
import urllib
from PIL import Image
from torchvision import transforms as T


midas = torch.hub.load("intel-isl/MiDaS", "DPT_Large") 
midas.eval()


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
midas.to(device)


midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms")

transform = midas_transforms.dpt_transform

# %%
img = cv2.imread("Test_Images\\bottle2.jpg")  
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


input_batch = transform(img).to(device)

# Predict depth
with torch.no_grad():
    prediction = midas(input_batch)

# Resize the output to match the input size
prediction = torch.nn.functional.interpolate(
    prediction.unsqueeze(1),
    size=img.shape[:2],
    mode="bicubic",
    align_corners=False,
).squeeze()

# Normalize the prediction for better visualization
depth_map = prediction.cpu().numpy()
depth_map = cv2.normalize(depth_map, None, 0, 255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)


cv2.imwrite("Test_Image_results\\depth_map1.jpg", depth_map)
cv2.waitKey(0)
# Out:
# -1
